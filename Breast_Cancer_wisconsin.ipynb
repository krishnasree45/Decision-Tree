# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import datasets
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

import pandas as pd
from sklearn.datasets import load_breast_cancer
# loading the data from sklearn
breast_cancer_dataset = datasets.load_breast_cancer()
data = load_breast_cancer()

# %%
# loading the data to a data frame
data_frame = pd.DataFrame(breast_cancer_dataset.data, columns = breast_cancer_dataset.feature_names)
data_frame['label'] = breast_cancer_dataset.target
X = data_frame.drop(columns='label', axis=1)
Y = data_frame['label']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
clf = svm.SVC()
# instantiate classifier with default hyperparameters
clf = svm.SVC(decision_function_shape='ovo')
clf.fit(X_train, Y_train)


# make predictions on test set
y_pred= clf.predict(X_test)



print('Model accuracy score with default hyperparameters: {0:0.4f}'. format(accuracy_score(Y_test, y_pred)))
print(accuracy_score(Y_test, y_pred))
print(confusion_matrix(Y_test, y_pred))
print(classification_report(Y_test, y_pred))
# Out:
# Model accuracy score with default hyperparameters: 0.9035
# 0.9035087719298246
# [[38  7]
#  [ 4 65]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87        45
#            1       0.90      0.94      0.92        69
#
#     accuracy                           0.90       114
#    macro avg       0.90      0.89      0.90       114
# weighted avg       0.90      0.90      0.90       114

# %%
import tensorflow as tf
from tensorflow.keras import layers
import pandas as pd
import numpy as np
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.utils import to_categorical

# Splitting the dataset in 80:20 ratio
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# Create a deep learning model with 3 dense layers
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid') # Final dense layer activation function is Sigmoid as its classification
  ])

model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Fit the model
model.fit(X_train, y_train, batch_size=50, epochs=100) 
loss, accuracy = model.evaluate(X_test, y_test, verbose=0) 

print('Test loss:', loss)
print('Test accuracy:', accuracy)
# make predictions on test set
y_pred = model.predict(X_test) \
print(classification_report(y_test, y_pred))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 2ms/step - loss: 0.0000e+00 - accuracy: 0.4330
# Epoch 2/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 4/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 5/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 6/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 7/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 8/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 9/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 10/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 11/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 12/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 13/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 14/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 15/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 16/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 17/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 18/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 19/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 20/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 21/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 22/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 23/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 24/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 25/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 26/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 27/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 28/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 29/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 30/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 31/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 32/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 33/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 34/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 35/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 36/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 37/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 38/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 39/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 40/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 41/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 42/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 43/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 44/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 45/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 46/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 47/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 48/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 49/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 50/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 51/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 52/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 53/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 54/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 55/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 56/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 57/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 58/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 59/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 60/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 61/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 62/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 63/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 64/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 65/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 66/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 67/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 68/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 69/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 70/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 71/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 72/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 73/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 74/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 75/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 76/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 77/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 78/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 79/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 80/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 81/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 82/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 83/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 84/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 85/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 86/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 87/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 88/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 89/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 90/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 91/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 92/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 93/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 94/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 95/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 96/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 97/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 98/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 99/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Epoch 100/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3626
# Test loss: 0.0
# Test accuracy: 0.41228070855140686
# 4/4 [==============================] - 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.41      1.00      0.58        47
#            1       0.00      0.00      0.00        67
#
#     accuracy                           0.41       114
#    macro avg       0.21      0.50      0.29       114
# weighted avg       0.17      0.41      0.24       114
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
